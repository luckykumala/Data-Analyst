# %% [markdown]
# Sebelum memulai kita melakukan import library dan import csv yang akan digunakan.

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
df=pd.read_csv("/content/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 7038          Yes               Yes             DSL            Yes
# 7039          Yes               Yes     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
# 7042          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 7038           No              Yes         Yes         Yes             Yes
# ...

# %% [markdown]
# DI sini terlihat ada kolom customerID yang tidak perlu kita olah untuk tugas saat ini, jadi kita hapus untuk memudahkannya.

# %%
df.drop('customerID', axis=1, inplace=True)
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# Terlihat dari info di bawah bahwa TotalCharges yang seharusnya berbentuk Float menjadi object dan tidak terindikasi adanya NaN.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# Akan tetapi ketika kita melakukan sortir di TotalCharges tidak ada isi berbeda dibandingkan saat kita periksa lima teratas dan lima terbawah.

# %%
df_sorted_TotalCharges = df.sort_values(by='TotalCharges', ascending = True)
df_sorted_TotalCharges.head()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 936   Female              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 753     Male              0      No        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 936             No             DSL                  Yes                  Yes
# 3826           Yes              No  No internet service  No internet service
# 4380            No              No  No internet service  No internet service
# 753             No              No  No internet service  No internet service
# 5218            No              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %% [markdown]
# Setelah ini kita akan mengubah tipe TotalCharges menjadi tipe numeric(float) sedangkan SeniorCitizen menjadi object

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df['SeniorCitizen']=df['SeniorCitizen'].astype('object')

# %% [markdown]
# Setelahnya saya memeriksa lagi, dan terlihat bahwa data tersebut memiliki NaN.

# %%
df.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# Untuk mengatasi NaN ada beberapa hal, pada tugas ini saya akan mengatasi dengan membuat variable baru dengan data yang sama tetapi membuang NaN.

# %%
df_drop=df.dropna()

# %% [markdown]
# Terlihat sekarang sudah tidak ada NaN karena sudah dibuang. Setelahnya kita bisa membuat dummies untuk data kita.

# %%
df_drop.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df_dummy = pd.get_dummies(df_drop)
df_dummy.head()
# Out:
#    tenure  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0       1           29.85         29.85              1            0
# 1      34           56.95       1889.50              0            1
# 2       2           53.85        108.15              0            1
# 3      45           42.30       1840.75              0            1
# 4       2           70.70        151.65              1            0
#
#    SeniorCitizen_0  SeniorCitizen_1  Partner_No  Partner_Yes  Dependents_No  \
# 0                1                0           0            1              1
# 1                1                0           1            0              1
# 2                1                0           1            0              1
# 3                1                0           1            0              1
# 4                1                0           1            0              1
#
#    Dependents_Yes  PhoneService_No  PhoneService_Yes  MultipleLines_No  \
# ...

# %%
print(df_drop.shape)
# Out:
# (7032, 20)

# %% [markdown]
# Setelah itu tahap selanjutnya adalah melakukan pengecekan terhadap data apakah memiliki anomali ataupun outlier.

# %%
import matplotlib.pyplot as plt
df_exc= df_drop.select_dtypes(exclude=['object'])
abc=df_exc.shape
i=0
while i < abc[1]:
  plt.boxplot(df_dummy[df_dummy.columns[i]])
  print([df_dummy.columns[i]])
  plt.show()
  i+=1
# Out:
# ['tenure']
# ['MonthlyCharges']
# ['TotalCharges']

# %%
def outlier(df , column):
    global lower,upper
    q25, q75 = np.quantile(df[column], 0.25), np.quantile(df[column], 0.75)
    # calculate the IQR
    iqr = q75 - q25
    # calculate the outlier
    cut_off = iqr * 1.5
    # calculate the lower and upper bound value
    lower, upper = q25 - cut_off, q75 + cut_off
    print(column, 'The IQR is',iqr,'\nThe lower bound value is', lower, '\nThe upper bound value is', upper)
    # Calculate the number of records below and above lower and above bound value respectively
    df1 = df[df[column] > upper]
    df2 = df[df[column] < lower]
    return print('Total number of outliers are', df1.shape[0]+ df2.shape[0],'\n')

# %%
i=0
totalcolumn=df_exc.shape
while i < totalcolumn[1]:
  outlier(df_exc, df_exc.columns[i])
  i+=1
# Out:
# tenure The IQR is 46.0
# The lower bound value is -60.0
# The upper bound value is 124.0
# Total number of outliers are 0
#
# MonthlyCharges The IQR is 54.275
# The lower bound value is -45.824999999999996
# The upper bound value is 171.27499999999998
# Total number of outliers are 0
#
# TotalCharges The IQR is 3393.2875000000004
# The lower bound value is -4688.481250000001
# The upper bound value is 8884.66875
# Total number of outliers are 0

# %% [markdown]
# Terlihat di atas bahwa data tidak memiliki adanya terindikasi anomali dan outlier.
